# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# Data

# %%
# Load the data
data = pd.read_csv('MWG.csv', parse_dates=['Date'])

# Convert 'Price' column to numeric
data['Price'] = pd.to_numeric(data['Price'].str.replace(',', ''), errors='coerce')

# Set the 'Date' column as the index
data.set_index('Date', inplace=True)

# Sort the index
data.sort_index(inplace=True)

# Set the frequency of the index
data = data.asfreq('B')

# Fill missing values if any (forward fill)
data['Price'].fillna(method='ffill', inplace=True)

# Split the data into training and testing sets
train_data = data[:'2022-02-28']
test_data = data['2022-03-01':'2023-03-31']

train = train_data['Price'].values
test = test_data['Price'].values

scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train.reshape(-1, 1))
test_scaled = scaler.transform(test.reshape(-1, 1))
model_path = "GRU_mwg.h5"
# Out:
# C:\Users\minht\AppData\Local\Temp\ipykernel_10140\1534482072.py:17: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['Price'].fillna(method='ffill', inplace=True)

# %%
train_data
# Out:
#               Price    Open    High     Low   Vol. Change %
# Date
# 2018-01-02  31276.0  31,039  31,394  31,039  2.27M    0.76%
# 2018-01-03  31892.0  31,323  32,034  31,276  4.53M    1.97%
# 2018-01-04  31963.0  31,773  32,081  31,750  2.71M    0.22%
# 2018-01-05  31608.0  31,987  31,987  31,465  2.93M   -1.11%
# 2018-01-08  31110.0  31,394  31,513  31,039  3.01M   -1.58%
# ...             ...     ...     ...     ...    ...      ...
# 2022-02-22  68405.0  66,070  69,150  65,772  6.55M    2.84%
# 2022-02-23  68455.0  68,405  69,846  68,008  3.22M    0.07%
# 2022-02-24  67958.0  68,057  68,405  67,312  2.35M   -0.73%
# 2022-02-25  68355.0  68,008  69,448  67,560  5.38M    0.58%
# 2022-02-28  67560.0  67,809  68,554  67,312  3.60M   -1.16%
#
# [1085 rows x 6 columns]

# %%
train_scaled[0]
# Out:
# array([0.22860712])

# %%
train_scaled.shape
# Out:
# (1085, 1)

# %%
x_train, x_val = train_test_split(train_scaled, test_size=0.2, shuffle=False)
x_train.shape
# Out:
# (868, 1)

# %%
x_train[0]
# Out:
# array([0.22860712])

# %%
from keras.preprocessing.sequence import TimeseriesGenerator
n_input = 20
train_generator = TimeseriesGenerator(x_train, x_train, length=n_input, batch_size=1)
val_generator = TimeseriesGenerator(x_val, x_val, length=n_input, batch_size=1)
train_generator[0]
# Out:
# (array([[[0.22860712],
#          [0.2402665 ],
#          [0.24161036],
#          [0.23489107],
#          [0.22546514],
#          [0.22635474],
#          [0.2317491 ],
#          [0.22815286],
#          [0.22052505],
#          [0.22186891],
#          [0.22366703],
#          [0.21066379],
#          [0.217402  ],
#          [0.20843034],
#          [0.21291617],
#          [0.21291617],
#          [0.21291617],
#          [0.21514962],
#          [0.20708648],
#          [0.19183086]]]),
#  array([[0.20125679]]))

# %% [markdown]
# Model

# %%
from keras.models import Sequential
from keras.layers import GRU, Dense
from keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from keras.callbacks import ReduceLROnPlateau

model = Sequential()
model.add(GRU(64, activation='relu', input_shape=(n_input, 1)))
model.add(Dense(1))  
model.compile(optimizer=Adam(learning_rate=0.01), loss='mse')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 64)                12864
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 12929 (50.50 KB)
# Trainable params: 12929 (50.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001)
checkpoint_callback = ModelCheckpoint(
    filepath=model_path,
    monitor='val_loss',
    save_weights_only=False,
    save_best_only=True,
    verbose=1
)

# %%
history = model.fit(train_generator, validation_data=val_generator, batch_size=16, epochs=30, callbacks=[checkpoint_callback, reduce_lr])
# Out:
# Epoch 1/30
# 844/848 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 1: val_loss improved from inf to 0.00255, saving model to GRU_mwg.h5
# 848/848 [==============================] - 7s 6ms/step - loss: 0.0011 - val_loss: 0.0025 - lr: 0.0100
# Epoch 2/30
#  21/848 [..............................] - ETA: 4s - loss: 5.8526e-04
# d:\Python\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 846/848 [============================>.] - ETA: 0s - loss: 5.1498e-04
# Epoch 2: val_loss did not improve from 0.00255
# 848/848 [==============================] - 5s 6ms/step - loss: 5.1660e-04 - val_loss: 0.0026 - lr: 0.0100
# Epoch 3/30
# 847/848 [============================>.] - ETA: 0s - loss: 4.0518e-04
# Epoch 3: val_loss improved from 0.00255 to 0.00070, saving model to GRU_mwg.h5
# 848/848 [==============================] - 5s 6ms/step - loss: 4.0494e-04 - val_loss: 7.0305e-04 - lr: 0.0100
# Epoch 4/30
# 846/848 [============================>.] - ETA: 0s - loss: 3.3527e-04
# Epoch 4: val_loss did not improve from 0.00070
# 848/848 [==============================] - 5s 6ms/step - loss: 3.3481e-04 - val_loss: 0.0038 - lr: 0.0100
# Epoch 5/30
# 845/848 [============================>.] - ETA: 0s - loss: 3.4246e-04
# Epoch 5: val_loss did not improve from 0.00070
# 848/848 [==============================] - 5s 6ms/step - loss: 3.4175e-04 - val_loss: 7.2588e-04 - lr: 0.0100
# Epoch 6/30
# 848/848 [==============================] - ETA: 0s - loss: 3.6932e-04
# Epoch 6: val_loss did not improve from 0.00070
# 848/848 [==============================] - 5s 6ms/step - loss: 3.6932e-04 - val_loss: 0.0011 - lr: 0.0100
# Epoch 7/30
# 842/848 [============================>.] - ETA: 0s - loss: 2.8890e-04
# Epoch 7: val_loss did not improve from 0.00070
# 848/848 [==============================] - 5s 6ms/step - loss: 2.8777e-04 - val_loss: 0.0017 - lr: 0.0100
# Epoch 8/30
# 846/848 [============================>.] - ETA: 0s - loss: 3.2993e-04
# Epoch 8: val_loss did not improve from 0.00070
# 848/848 [==============================] - 5s 6ms/step - loss: 3.2935e-04 - val_loss: 0.0012 - lr: 0.0100
# Epoch 9/30
# 843/848 [============================>.] - ETA: 0s - loss: 1.7141e-04
# Epoch 9: val_loss improved from 0.00070 to 0.00045, saving model to GRU_mwg.h5
# 848/848 [==============================] - 5s 6ms/step - loss: 1.7062e-04 - val_loss: 4.4594e-04 - lr: 0.0020
# Epoch 10/30
# 842/848 [============================>.] - ETA: 0s - loss: 1.6787e-04
# Epoch 10: val_loss did not improve from 0.00045
# 848/848 [==============================] - 5s 6ms/step - loss: 1.6684e-04 - val_loss: 5.4107e-04 - lr: 0.0020
# Epoch 11/30
# 843/848 [============================>.] - ETA: 0s - loss: 1.7061e-04
# Epoch 11: val_loss improved from 0.00045 to 0.00044, saving model to GRU_mwg.h5
# 848/848 [==============================] - 5s 6ms/step - loss: 1.6987e-04 - val_loss: 4.4044e-04 - lr: 0.0020
# Epoch 12/30
# 842/848 [============================>.] - ETA: 0s - loss: 1.8366e-04
# Epoch 12: val_loss did not improve from 0.00044
# 848/848 [==============================] - 5s 6ms/step - loss: 1.8271e-04 - val_loss: 5.3997e-04 - lr: 0.0020
# Epoch 13/30
# 845/848 [============================>.] - ETA: 0s - loss: 1.9075e-04
# Epoch 13: val_loss did not improve from 0.00044
# 848/848 [==============================] - 5s 6ms/step - loss: 1.9021e-04 - val_loss: 4.4613e-04 - lr: 0.0020
# Epoch 14/30
# 843/848 [============================>.] - ETA: 0s - loss: 1.8046e-04
# Epoch 14: val_loss did not improve from 0.00044
# 848/848 [==============================] - 5s 6ms/step - loss: 1.7986e-04 - val_loss: 4.5330e-04 - lr: 0.0020
# Epoch 15/30
# 845/848 [============================>.] - ETA: 0s - loss: 1.5770e-04
# Epoch 15: val_loss improved from 0.00044 to 0.00043, saving model to GRU_mwg.h5
# 848/848 [==============================] - 5s 6ms/step - loss: 1.5716e-04 - val_loss: 4.3177e-04 - lr: 0.0010
# Epoch 16/30
# 841/848 [============================>.] - ETA: 0s - loss: 1.6172e-04
# Epoch 16: val_loss did not improve from 0.00043
# 848/848 [==============================] - 5s 6ms/step - loss: 1.6100e-04 - val_loss: 4.4773e-04 - lr: 0.0010
# Epoch 17/30
# 847/848 [============================>.] - ETA: 0s - loss: 1.5809e-04
# Epoch 17: val_loss did not improve from 0.00043
# 848/848 [==============================] - 5s 6ms/step - loss: 1.5807e-04 - val_loss: 4.5259e-04 - lr: 0.0010
# Epoch 18/30
# 846/848 [============================>.] - ETA: 0s - loss: 1.6057e-04
# Epoch 18: val_loss did not improve from 0.00043
# 848/848 [==============================] - 5s 6ms/step - loss: 1.6020e-04 - val_loss: 5.6237e-04 - lr: 0.0010
# Epoch 19/30
# 844/848 [============================>.] - ETA: 0s - loss: 1.5960e-04
# Epoch 19: val_loss did not improve from 0.00043
# 848/848 [==============================] - 5s 6ms/step - loss: 1.5915e-04 - val_loss: 5.1164e-04 - lr: 0.0010
# Epoch 20/30
# 842/848 [============================>.] - ETA: 0s - loss: 1.5834e-04
# Epoch 20: val_loss did not improve from 0.00043
# 848/848 [==============================] - 5s 6ms/step - loss: 1.5808e-04 - val_loss: 4.7468e-04 - lr: 0.0010
# Epoch 21/30
# 847/848 [============================>.] - ETA: 0s - loss: 1.5251e-04
# Epoch 21: val_loss did not improve from 0.00043
# 848/848 [==============================] - 5s 6ms/step - loss: 1.5235e-04 - val_loss: 4.8735e-04 - lr: 0.0010
# Epoch 22/30
# 845/848 [============================>.] - ETA: 0s - loss: 1.6218e-04
# Epoch 22: val_loss did not improve from 0.00043
# 848/848 [==============================] - 5s 6ms/step - loss: 1.6165e-04 - val_loss: 4.5652e-04 - lr: 0.0010
# Epoch 23/30
# 847/848 [============================>.] - ETA: 0s - loss: 1.6292e-04
# Epoch 23: val_loss did not improve from 0.00043
# 848/848 [==============================] - 5s 6ms/step - loss: 1.6274e-04 - val_loss: 4.6976e-04 - lr: 0.0010
# Epoch 24/30
# 840/848 [============================>.] - ETA: 0s - loss: 1.5763e-04
# Epoch 24: val_loss did not improve from 0.00043
# 848/848 [==============================] - 5s 6ms/step - loss: 1.5721e-04 - val_loss: 4.3936e-04 - lr: 0.0010
# Epoch 25/30
# 844/848 [============================>.] - ETA: 0s - loss: 1.5864e-04
# Epoch 25: val_loss did not improve from 0.00043
# 848/848 [==============================] - 5s 6ms/step - loss: 1.5880e-04 - val_loss: 4.4778e-04 - lr: 0.0010
# Epoch 26/30
# 847/848 [============================>.] - ETA: 0s - loss: 1.5718e-04
# Epoch 26: val_loss improved from 0.00043 to 0.00043, saving model to GRU_mwg.h5
# 848/848 [==============================] - 5s 6ms/step - loss: 1.5706e-04 - val_loss: 4.2696e-04 - lr: 0.0010
# Epoch 27/30
# 844/848 [============================>.] - ETA: 0s - loss: 1.5896e-04
# Epoch 27: val_loss did not improve from 0.00043
# 848/848 [==============================] - 5s 6ms/step - loss: 1.6140e-04 - val_loss: 4.9800e-04 - lr: 0.0010
# Epoch 28/30
# 846/848 [============================>.] - ETA: 0s - loss: 1.5745e-04
# Epoch 28: val_loss did not improve from 0.00043
# 848/848 [==============================] - 5s 6ms/step - loss: 1.5717e-04 - val_loss: 5.9944e-04 - lr: 0.0010
# Epoch 29/30
# 840/848 [============================>.] - ETA: 0s - loss: 1.5722e-04
# Epoch 29: val_loss did not improve from 0.00043
# 848/848 [==============================] - 5s 6ms/step - loss: 1.5604e-04 - val_loss: 4.5001e-04 - lr: 0.0010
# Epoch 30/30
# 847/848 [============================>.] - ETA: 0s - loss: 1.5906e-04
# Epoch 30: val_loss did not improve from 0.00043
# 848/848 [==============================] - 6s 7ms/step - loss: 1.5891e-04 - val_loss: 4.6385e-04 - lr: 0.0010

# %%
loss = model.history.history['loss']
plt.plot(range(len(loss)), loss)

# %%
val_loss = model.history.history['val_loss']
plt.plot(range(len(val_loss)), val_loss)

# %% [markdown]
# Evaluation

# %%
model = tf.keras.models.load_model(model_path)

# %%
y_pred = model.predict(train_scaled)
# Out:
# 34/34 [==============================] - 0s 1ms/step

# %%
y_pred = scaler.inverse_transform(y_pred)
x_train = scaler.inverse_transform(x_train)
x_val = scaler.inverse_transform(x_val)
plt.plot(range(len(x_train)-1), y_pred[:len(x_train)-1], color ="orange", label = "Train Pred")
plt.plot(range(len(x_train)-1), x_train[1:], color ="green", label = "Train Actual")
plt.plot(range(len(x_train)-1,len(train_scaled)-1), y_pred[len(x_train)-1:-1], color ="red", label = "Val Pred")
plt.plot(range(len(x_train)-1,len(train_scaled)-1), x_val, color ="blue", label = "Val Actual")
plt.legend()

# %%
data_scaled = np.concatenate((train_scaled, test_scaled))
pred = model.predict(data_scaled)
pred = pred[-len(test_scaled)-1:-1]
# Out:
# 43/43 [==============================] - 0s 1ms/step

# %%
len(pred)
# Out:
# 284

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import math

plot_pred = scaler.inverse_transform(pred)
actual = scaler.inverse_transform(test_scaled)

def mean_absolute_percentage_error(y_true, y_pred): 
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100


r2 = r2_score(test_scaled, pred)
print("R-squared:", r2)
mape = mean_absolute_percentage_error(actual, plot_pred)
print("MAPE:", mape)
rmse = math.sqrt(mean_squared_error(actual, plot_pred))
print("RMSE:", rmse)
# Out:
# R-squared: 0.9854582981162439
# MAPE: 1.9784996605462388
# RMSE: 1596.5088030953464

# %%
plt.plot(range(len(actual)), plot_pred, color ="orange", label = "Test Pred")
plt.plot(range(len(actual)), actual, color ="green", label = "Test Actual")
plt.legend()
